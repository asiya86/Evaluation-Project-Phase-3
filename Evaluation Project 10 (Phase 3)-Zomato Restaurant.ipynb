# %% [markdown]
# # Problem Statement:

# %% [markdown]
# Zomato Data Analysis is one of the most useful analysis for foodies who want to taste the best
# cuisines of every part of the world which lies in their budget. This analysis is also for those who
# want to find the value for money restaurants in various parts of the country for the cuisines.
# Additionally, this analysis caters the needs of people who are striving to get the best cuisine of
# the country and which locality of that country serves that cuisines with maximum number of
# restaurants.
#
# Data Storage:
# This problem statement contains two datasets- Zomato.csv and country_code.csv.
# Country_code.csv contains two variables:
# • Country code
# • Country name

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings 
warnings.filterwarnings('ignore')

from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/dataset4/main/zomato.csv",encoding='ISO-8859-1')

# %%
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
#                                                 Address  \
# 0     Third Floor, Century City Mall, Kalayaan Avenu...
# 1     Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2     Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3     Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4     Third Floor, Mega Atrium, SM Megamall, Ortigas...
# ...                                                 ...
# 9546  Kemankeô Karamustafa Paôa Mahallesi, RÛ±htÛ±...
# 9547  Koôuyolu Mahallesi, Muhittin íìstí_ndaÛô Cadd...
# 9548  Kuruí_eôme Mahallesi, Muallim Naci Caddesi, N...
# 9549  Kuruí_eôme Mahallesi, Muallim Naci Caddesi, N...
# 9550  CafeaÛôa Mahallesi, BademaltÛ± Sokak, No 21/B,...
#
#                                         Locality  \
# 0      Century City Mall, Poblacion, Makati City
# 1     Little Tokyo, Legaspi Village, Makati City
# 2     Edsa Shangri-La, Ortigas, Mandaluyong City
# 3         SM Megamall, Ortigas, Mandaluyong City
# 4         SM Megamall, Ortigas, Mandaluyong City
# ...                                          ...
# 9546                                    Karakí_y
# 9547                                   Koôuyolu
# 9548                                 Kuruí_eôme
# 9549                                 Kuruí_eôme
# 9550                                        Moda
#
#                                        Locality Verbose   Longitude  \
# 0     Century City Mall, Poblacion, Makati City, Mak...  121.027535
# 1     Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101
# 2     Edsa Shangri-La, Ortigas, Mandaluyong City, Ma...  121.056831
# 3     SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.056475
# 4     SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.057508
# ...                                                 ...         ...
# 9546                                Karakí_y, ÛÁstanbul   28.977392
# 9547                               Koôuyolu, ÛÁstanbul   29.041297
# 9548                             Kuruí_eôme, ÛÁstanbul   29.034640
# 9549                             Kuruí_eôme, ÛÁstanbul   29.036019
# 9550                                    Moda, ÛÁstanbul   29.026016
#
#        Latitude                          Cuisines  ...          Currency  \
# 0     14.565443        French, Japanese, Desserts  ...  Botswana Pula(P)
# 1     14.553708                          Japanese  ...  Botswana Pula(P)
# 2     14.581404  Seafood, Asian, Filipino, Indian  ...  Botswana Pula(P)
# 3     14.585318                   Japanese, Sushi  ...  Botswana Pula(P)
# 4     14.584450                  Japanese, Korean  ...  Botswana Pula(P)
# ...         ...                               ...  ...               ...
# 9546  41.022793                           Turkish  ...  Turkish Lira(TL)
# 9547  41.009847   World Cuisine, Patisserie, Cafe  ...  Turkish Lira(TL)
# 9548  41.055817            Italian, World Cuisine  ...  Turkish Lira(TL)
# 9549  41.057979                   Restaurant Cafe  ...  Turkish Lira(TL)
# 9550  40.984776                              Cafe  ...  Turkish Lira(TL)
#
#      Has Table booking Has Online delivery Is delivering now  \
# 0                  Yes                  No                No
# 1                  Yes                  No                No
# 2                  Yes                  No                No
# 3                   No                  No                No
# 4                  Yes                  No                No
# ...                ...                 ...               ...
# 9546                No                  No                No
# 9547                No                  No                No
# 9548                No                  No                No
# 9549                No                  No                No
# 9550                No                  No                No
#
#      Switch to order menu Price range  Aggregate rating  Rating color  \
# 0                      No           3               4.8    Dark Green
# 1                      No           3               4.5    Dark Green
# 2                      No           4               4.4         Green
# 3                      No           4               4.9    Dark Green
# 4                      No           4               4.8    Dark Green
# ...                   ...         ...               ...           ...
# 9546                   No           3               4.1         Green
# 9547                   No           3               4.2         Green
# 9548                   No           4               3.7        Yellow
# 9549                   No           4               4.0         Green
# 9550                   No           2               4.0         Green
#
#      Rating text Votes
# 0      Excellent   314
# 1      Excellent   591
# 2      Very Good   270
# 3      Excellent   365
# 4      Excellent   229
# ...          ...   ...
# 9546   Very Good   788
# 9547   Very Good  1034
# 9548        Good   661
# 9549   Very Good   901
# 9550   Very Good   591
#
# [9551 rows x 21 columns]

# %%
datacode=pd.read_excel('Country-Code.xls')

# %%
datacode
# Out:
#     Country Code         Country
# 0              1           India
# 1             14       Australia
# 2             30          Brazil
# 3             37          Canada
# 4             94       Indonesia
# 5            148     New Zealand
# 6            162     Phillipines
# 7            166           Qatar
# 8            184       Singapore
# 9            189    South Africa
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %%
data = pd.merge(df, datacode, how='inner', on ='Country Code')

# %%
data
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
#                                                 Address  \
# 0     Third Floor, Century City Mall, Kalayaan Avenu...
# 1     Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2     Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3     Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4     Third Floor, Mega Atrium, SM Megamall, Ortigas...
# ...                                                 ...
# 9546  Kemankeô Karamustafa Paôa Mahallesi, RÛ±htÛ±...
# 9547  Koôuyolu Mahallesi, Muhittin íìstí_ndaÛô Cadd...
# 9548  Kuruí_eôme Mahallesi, Muallim Naci Caddesi, N...
# 9549  Kuruí_eôme Mahallesi, Muallim Naci Caddesi, N...
# 9550  CafeaÛôa Mahallesi, BademaltÛ± Sokak, No 21/B,...
#
#                                         Locality  \
# 0      Century City Mall, Poblacion, Makati City
# 1     Little Tokyo, Legaspi Village, Makati City
# 2     Edsa Shangri-La, Ortigas, Mandaluyong City
# 3         SM Megamall, Ortigas, Mandaluyong City
# 4         SM Megamall, Ortigas, Mandaluyong City
# ...                                          ...
# 9546                                    Karakí_y
# 9547                                   Koôuyolu
# 9548                                 Kuruí_eôme
# 9549                                 Kuruí_eôme
# 9550                                        Moda
#
#                                        Locality Verbose   Longitude  \
# 0     Century City Mall, Poblacion, Makati City, Mak...  121.027535
# 1     Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101
# 2     Edsa Shangri-La, Ortigas, Mandaluyong City, Ma...  121.056831
# 3     SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.056475
# 4     SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.057508
# ...                                                 ...         ...
# 9546                                Karakí_y, ÛÁstanbul   28.977392
# 9547                               Koôuyolu, ÛÁstanbul   29.041297
# 9548                             Kuruí_eôme, ÛÁstanbul   29.034640
# 9549                             Kuruí_eôme, ÛÁstanbul   29.036019
# 9550                                    Moda, ÛÁstanbul   29.026016
#
#        Latitude                          Cuisines  ...  Has Table booking  \
# 0     14.565443        French, Japanese, Desserts  ...                Yes
# 1     14.553708                          Japanese  ...                Yes
# 2     14.581404  Seafood, Asian, Filipino, Indian  ...                Yes
# 3     14.585318                   Japanese, Sushi  ...                 No
# 4     14.584450                  Japanese, Korean  ...                Yes
# ...         ...                               ...  ...                ...
# 9546  41.022793                           Turkish  ...                 No
# 9547  41.009847   World Cuisine, Patisserie, Cafe  ...                 No
# 9548  41.055817            Italian, World Cuisine  ...                 No
# 9549  41.057979                   Restaurant Cafe  ...                 No
# 9550  40.984776                              Cafe  ...                 No
#
#      Has Online delivery Is delivering now Switch to order menu Price range  \
# 0                     No                No                   No           3
# 1                     No                No                   No           3
# 2                     No                No                   No           4
# 3                     No                No                   No           4
# 4                     No                No                   No           4
# ...                  ...               ...                  ...         ...
# 9546                  No                No                   No           3
# 9547                  No                No                   No           3
# 9548                  No                No                   No           4
# 9549                  No                No                   No           4
# 9550                  No                No                   No           2
#
#      Aggregate rating  Rating color  Rating text Votes      Country
# 0                 4.8    Dark Green    Excellent   314  Phillipines
# 1                 4.5    Dark Green    Excellent   591  Phillipines
# 2                 4.4         Green    Very Good   270  Phillipines
# 3                 4.9    Dark Green    Excellent   365  Phillipines
# 4                 4.8    Dark Green    Excellent   229  Phillipines
# ...               ...           ...          ...   ...          ...
# 9546              4.1         Green    Very Good   788       Turkey
# 9547              4.2         Green    Very Good  1034       Turkey
# 9548              3.7        Yellow         Good   661       Turkey
# 9549              4.0         Green    Very Good   901       Turkey
# 9550              4.0         Green    Very Good   591       Turkey
#
# [9551 rows x 22 columns]

# %%
# checking shapes

data.shape
# Out:
# (9551, 22)

# %%
# Observations:

# This Dataset has 9551 rows and 22 columns. Let's study the column's names and their charectaristics.

# %%
# checking columns names

data.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
#  15  Switch to order menu  9551 non-null   object
#  16  Price range           9551 non-null   int64
#  17  Aggregate rating      9551 non-null   float64
#  18  Rating color          9551 non-null   object
#  19  Rating text           9551 non-null   object
#  20  Votes                 9551 non-null   int64
#  21  Country               9551 non-null   object
# dtypes: float64(3), int64(5), object(14)
# memory usage: 1.7+ MB

# %%
# Observations:

# Among 20 features, 14 are object datatype and 5 are numerical data.

# For all 21 columns, all are non-null value except Cuisines.

# %%
data.nunique()
# Out:
# Restaurant ID           9551
# Restaurant Name         7446
# Country Code              15
# City                     141
# Address                 8918
# Locality                1208
# Locality Verbose        1265
# Longitude               8120
# Latitude                8677
# Cuisines                1825
# Average Cost for two     140
# Currency                  12
# Has Table booking          2
# Has Online delivery        2
# Is delivering now          2
# Switch to order menu       1
# Price range                4
# Aggregate rating          33
# Rating color               6
# Rating text                6
# Votes                   1012
# Country                   15
# dtype: int64

# %%
# Observations:

# Here Switch to order menu have 1 value for total dataset. Let's drop it.

# Restaurant ID have different value for every different entries. Drop this column.

# %% [markdown]
# # Drop Unnecessary columns:

# %%
data.drop(["Restaurant ID", 'Switch to order menu'], axis=1, inplace= True)
data.shape
# Out:
# (9551, 20)

# %% [markdown]
# # Renaming: the columns to make it easy

# %%
data.rename(columns={'Restaurant Name': 'Restaurant_Name', 'Country Code': 'Country_Code', 'Locality Verbose': 'Locality_Verbose', 
        'Average Cost for two':'Average_Cost_for_two','Has Table booking':'Has_Table_booking',
        'Has Online delivery':'Has_Online_delivery', 'Is delivering now':'Is_delivering_now','Rating text':'Rating_text',
        'Price range':'Price_range', 'Aggregate rating':'Aggregate_rating','Rating color':'Rating_color'}, inplace=True)

# %% [markdown]
# # Checking duplicate:

# %%
data.duplicated().sum()
# Out:
# 0

# %%
# Observatios:

# This dataset does not have any duplicates

# %% [markdown]
# # Let check if any whitespace, 'NA', '?' or '-' exist in dataset

# %%
data.isin([' ','NA','-']).sum().any()
# Out:
# False

# %%
data.isin(['?']).sum().any()
# Out:
# False

# %%
# Observations:

# Dataset is free from ' ', 'NA' ,'-', '?'

# %% [markdown]
# # Checking Null:

# %%
null_val= data.isna().sum()
null_val_per =(null_val/data.shape[0])*100
l= [null_val, null_val_per]
print("missing value details \n\n", pd.concat(l, axis =1, keys =['Null Values', 'Null Values %']).sort_values('Null Values'))
# Out:
# missing value details
#
#                        Null Values  Null Values %
# Restaurant_Name                 0       0.000000
# Rating_text                     0       0.000000
# Rating_color                    0       0.000000
# Aggregate_rating                0       0.000000
# Price_range                     0       0.000000
# Is_delivering_now               0       0.000000
# Has_Online_delivery             0       0.000000
# Has_Table_booking               0       0.000000
# Currency                        0       0.000000
# Average_Cost_for_two            0       0.000000
# Latitude                        0       0.000000
# Longitude                       0       0.000000
# Locality_Verbose                0       0.000000
# Locality                        0       0.000000
# Address                         0       0.000000
# City                            0       0.000000
# Country_Code                    0       0.000000
# Votes                           0       0.000000
# Country                         0       0.000000
# Cuisines                        9       0.094231

# %%
sns.heatmap(data.isnull(),cbar=False)
plt.show()

# %%
# Observations:

# Only cusines has null values. Since its a catergorical column will impute it with mode

# %% [markdown]
# # Missing value imputation:

# %%
data['Cuisines'].mode()
# Out:
# 0    North Indian
# Name: Cuisines, dtype: object

# %%
data['Cuisines'].fillna(data['Cuisines'].mode()[0],inplace=True)

# %%
null_val= data.isna().sum()
null_val_per =(null_val/data.shape[0])*100
l= [null_val, null_val_per]
print("missing value details \n\n", pd.concat(l, axis =1, keys =['Null Values', 'Null Values %']).sort_values('Null Values'))
# Out:
# missing value details
#
#                        Null Values  Null Values %
# Restaurant_Name                 0            0.0
# Rating_text                     0            0.0
# Rating_color                    0            0.0
# Aggregate_rating                0            0.0
# Price_range                     0            0.0
# Is_delivering_now               0            0.0
# Has_Online_delivery             0            0.0
# Has_Table_booking               0            0.0
# Currency                        0            0.0
# Average_Cost_for_two            0            0.0
# Cuisines                        0            0.0
# Latitude                        0            0.0
# Longitude                       0            0.0
# Locality_Verbose                0            0.0
# Locality                        0            0.0
# Address                         0            0.0
# City                            0            0.0
# Country_Code                    0            0.0
# Votes                           0            0.0
# Country                         0            0.0

# %%
# Observation

# No null values present in the dataset

# %% [markdown]
# # Statistical features:

# %%
data.describe()
# Out:
#        Country_Code    Longitude     Latitude  Average_Cost_for_two  \
# count   9551.000000  9551.000000  9551.000000           9551.000000
# mean      18.365616    64.126574    25.854381           1199.210763
# std       56.750546    41.467058    11.007935          16121.183073
# min        1.000000  -157.948486   -41.330428              0.000000
# 25%        1.000000    77.081343    28.478713            250.000000
# 50%        1.000000    77.191964    28.570469            400.000000
# 75%        1.000000    77.282006    28.642758            700.000000
# max      216.000000   174.832089    55.976980         800000.000000
#
#        Price_range  Aggregate_rating         Votes
# count  9551.000000       9551.000000   9551.000000
# mean      1.804837          2.666370    156.909748
# std       0.905609          1.516378    430.169145
# min       1.000000          0.000000      0.000000
# 25%       1.000000          2.500000      5.000000
# 50%       2.000000          3.200000     31.000000
# 75%       2.000000          3.700000    131.000000
# max       4.000000          4.900000  10934.000000

# %%
data.describe(include=object).T
# Out:
#                     count unique                         top  freq
# Restaurant_Name      9551   7446             Cafe Coffee Day    83
# City                 9551    141                   New Delhi  5473
# Address              9551   8918            Sector 41, Noida    11
# Locality             9551   1208             Connaught Place   122
# Locality_Verbose     9551   1265  Connaught Place, New Delhi   122
# Cuisines             9551   1825                North Indian   945
# Currency             9551     12          Indian Rupees(Rs.)  8652
# Has_Table_booking    9551      2                          No  8393
# Has_Online_delivery  9551      2                          No  7100
# Is_delivering_now    9551      2                          No  9517
# Rating_color         9551      6                      Orange  3737
# Rating_text          9551      6                     Average  3737
# Country              9551     15                       India  8652

# %%
# Observations:

# Outliers are present in numerical dataset.

# Price range is discrete numerical data.

# Here there are 2 target variable. They are, Average_Cost_for_two and Price_range.

# Average_Cost_for_two is a numerical data(target1).

# Price_range is a numerical data(target2).

# %% [markdown]
# # Differentiate Numerical and Categorical Data:

# %%
data.columns.to_series().groupby(data.dtypes).groups
# Out:
# {int64: ['Country_Code', 'Average_Cost_for_two', 'Price_range', 'Votes'], float64: ['Longitude', 'Latitude', 'Aggregate_rating'], object: ['Restaurant_Name', 'City', 'Address', 'Locality', 'Locality_Verbose', 'Cuisines', 'Currency', 'Has_Table_booking', 'Has_Online_delivery', 'Is_delivering_now', 'Rating_color', 'Rating_text', 'Country']}

# %%
num_col= ['Country_Code', 'Average_Cost_for_two', 'Price_range', 'Votes', 'Longitude', 'Latitude', 'Aggregate_rating']

cat_col= ['Restaurant_Name', 'City', 'Address', 'Locality', 'Locality_Verbose', 'Cuisines', 'Currency', 
               'Has_Table_booking', 'Has_Online_delivery', 'Is_delivering_now', 'Rating_color', 'Rating_text','Country']

# %% [markdown]
# # Exploratory Data Analysis(EDA):

# %% [markdown]
# # Univariate Analysis (Categorical and Numerical Data Analysis):

# %%
data['Currency'].value_counts()
# Out:
# Indian Rupees(Rs.)        8652
# Dollar($)                  482
# Pounds(£)                  80
# Brazilian Real(R$)          60
# Emirati Diram(AED)          60
# Rand(R)                     60
# NewZealand($)               40
# Turkish Lira(TL)            34
# Botswana Pula(P)            22
# Indonesian Rupiah(IDR)      21
# Qatari Rial(QR)             20
# Sri Lankan Rupee(LKR)       20
# Name: Currency, dtype: int64

# %%
plt.figure(figsize=(15,3))
sns.countplot(data["Currency"])
plt.xticks(rotation=50)
plt.show()

# %%
# Observations:

# Among 9551, 8652 is Indian Rupees(Rs.).

# Max is indian rupees.

# %%
# Has_Table_booking

data['Has_Table_booking'].value_counts()
# Out:
# No     8393
# Yes    1158
# Name: Has_Table_booking, dtype: int64

# %%
plt.subplots(figsize=(8,5))
data['Has_Table_booking'].value_counts().plot.pie(autopct='%2.1f%%', textprops ={ 'fontweight': 'bold','fontsize':10})
plt.title('Has_Table_booking', fontsize=15,fontweight ='bold')
plt.ylabel( ' ')
plt.show()

# %%
# Observations:

# Around 88% are customer's othat  Has_Table_booking.

# 12% customer did not book their table.

# %%
# Has_Online_delivery

data['Has_Online_delivery'].value_counts()
# Out:
# No     7100
# Yes    2451
# Name: Has_Online_delivery, dtype: int64

# %%
data['Has_Online_delivery'].value_counts().plot.pie(autopct='%2.1f%%', textprops ={ 'fontweight': 'bold','fontsize':10})
plt.title('Has_Online_delivery', fontsize=15,fontweight ='bold')
plt.ylabel( ' ')
plt.show()

# %%
# Is_delivering_now

data['Is_delivering_now'].value_counts().plot.pie(autopct='%2.1f%%', textprops ={ 'fontweight': 'bold','fontsize':10})
plt.ylabel( ' ')
plt.show()

# %%
# Observations:

# Around 75% customer has online delivery option.

# 99.6% customer is negative response on 'Is_delivering_now'.

# %%
# Rating_color

plt.subplots(figsize=(10,7))
data['Rating_color'].value_counts().plot.pie(autopct='%2.1f%%', textprops ={ 'fontweight': 'bold','fontsize':10})
plt.ylabel( ' ')
plt.show()

# %%
# Rating_text

plt.figure(figsize=(15,3))
sns.countplot(data["Rating_text"])
plt.xticks(rotation=50)
plt.show()

# %%
# Observations:

# Around 40% Rating_color is Orange.

# Maximum Rating_text is Average.

# %%
# Votes

plt.figure(figsize=(8,4))
sns.distplot(data['Votes'])
plt.show()

# %%
# Country_Code

plt.figure(figsize=(15,3))
sns.countplot(data["Country_Code"])
plt.xticks(rotation=50)
plt.show()

# %%
# Country

plt.figure(figsize=(15,3))
sns.countplot(data["Country"])
plt.xticks(rotation=50)
plt.show()

# %%
# Observations:

# Votes is a right skewed data. Maximum votes are for 0.

# Maximum case is from India and minimum is from Canada.

# %%
# Longitude

plt.figure(figsize=(8,4))
sns.distplot(data['Longitude'])
plt.show()

# %%
# Latitude

plt.figure(figsize=(8,4))
sns.distplot(data['Latitude'])
plt.show()

# %%
# Aggregate_rating

plt.figure(figsize=(15,3))
sns.countplot(data["Aggregate_rating"])
plt.xticks(rotation=50)
plt.show()

# %%
# Observations:

# Maximum Longitude range is 50-100.

# Maximum Latitude range is 20-40.

# Maximum Aggregate_rating is 0.0.

# %% [markdown]
# # Target Variable Exploration:

# %% [markdown]
# # 1. Average_Cost_for_two:

# %%
plt.figure(figsize=(25,5))
sns.countplot(data["Average_Cost_for_two"])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(18,4))
sns.distplot(data['Average_Cost_for_two'])
plt.show()

# %%
plt.figure(figsize=(18,5))
sns.violinplot(data['Average_Cost_for_two'], color='green')
plt.show()

# %%
print('Maximum Average_Cost_for_two value is:',data.Average_Cost_for_two.max())
print('Minimum Average_Cost_for_two value is:',data.Average_Cost_for_two.min())
print('Mean Average_Cost_for_two value is:',data.Average_Cost_for_two.mode()[0])
# Out:
# Maximum Average_Cost_for_two value is: 800000
# Minimum Average_Cost_for_two value is: 0
# Mean Average_Cost_for_two value is: 500

# %%
# Observations:

# Average_Cost_for_two is in between 100-1000.

# Average_Cost_for_two is right skewed.

# This is a continuous numerical data. Need Regression model to predict this.

# %% [markdown]
# # 2. Price_range:

# %%
plt.subplots(figsize=(8,7))
data['Price_range'].value_counts().plot.pie(autopct='%2.1f%%', textprops ={ 'fontweight': 'bold','fontsize':10})
plt.ylabel( ' ')
plt.show()

# %%
plt.figure(figsize=(8,3))
sns.countplot(data["Price_range"])
plt.show()

# %%
# Observations:

# Maximum Price_range is 1(around 47%).

# Price_range is a discrete numerical data.Needs classification model to predict this.

# %% [markdown]
# # Bivariate Analysis:

# %% [markdown]
# # Relation with two target variable, Price_range and Average_Cost_for_two:

# %%
plt.figure(figsize=(10,4))
sns.boxenplot(y = "Average_Cost_for_two", x= "Price_range", data = data)
plt.title('Comparison between two target variable', fontsize=15, fontweight='bold')
plt.show()

# %%
plt.figure(figsize=(10,4))
sns.barplot(y = "Average_Cost_for_two", x= "Price_range", data = data)
plt.title('Comparison between two target variable', fontsize=15, fontweight='bold')
plt.show()

# %%
# Observations:

# 1) For price range 1, Average_Cost_for_two is lowest.

# 2) Maximum Average_Cost_for_two is for orice range 3.

# 3) Outliers are present.

# %% [markdown]
# # Relation with different features and Average_Cost_for_two:

# %%
plt.figure(figsize=(18,5))
sns.boxplot(y = "Average_Cost_for_two", x= "Currency", data = data)
plt.title('Comparison between Average_Cost_for_two and Currency', fontsize=15, fontweight='bold')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.boxenplot(y = "Average_Cost_for_two", x= "Has_Table_booking", data = data)
plt.title('Comparison between Average_Cost_for_two and Has_Table_booking', fontsize=15, fontweight='bold')
plt.show()

# %%
plt.figure(figsize=(10,4))
sns.barplot(y = "Average_Cost_for_two", x= "Has_Table_booking", data = data, hue= 'Price_range')
plt.title('Comparison between Average_Cost_for_two and Has_Table_booking', fontsize=15, fontweight='bold')
plt.show()

# %%
# Observations:

# Maximum Average_Cost_for_two is for IND.

# Maximum customer have no booking of their table.

# Interestingly, the restaurant with price range level 4 have maximum table booking. 
# The customers who have decided to go for a high price restaurent, booked their table previously.

# %%
plt.figure(figsize=(18,5))
sns.swarmplot(x = "Average_Cost_for_two", y = "Aggregate_rating", data = data)
plt.title('Comparison between Average_Cost_for_two and Aggregate_rating', fontsize=15, fontweight='bold')
plt.show()

# %%
plt.figure(figsize=(18,5))
sns.barplot(x = "Average_Cost_for_two", y = "Aggregate_rating", data = data)
plt.title('Comparison between Average_Cost_for_two and Aggregate_rating', fontsize=15, fontweight='bold')
plt.show()

# %%
# Observations:

# For maximum case, if Average_Cost_for_two increased, Aggregate_rating also increased.

# %%
plt.figure(figsize=(18,5))
sns.scatterplot(x = "Average_Cost_for_two", y = "Votes", data = data, hue= 'Price_range')
plt.title('Comparison between Average_Cost_for_two and Votes', fontsize=15, fontweight='bold')
plt.show()

# %%
plt.figure(figsize=(18,5))
sns.barplot(x = "Average_Cost_for_two", y = "Votes", data = data)
plt.title('Comparison between Average_Cost_for_two and Votes', fontsize=15, fontweight='bold')
plt.show()

# %%
plt.figure(figsize=(18,5))
sns.barplot(y = "Average_Cost_for_two", x= "Country_Code", data = data, hue= 'Price_range')
plt.title('Comparison between Average_Cost_for_two and Country_Code', fontsize=15, fontweight='bold')
plt.show()

# %%
plt.figure(figsize=(18,5))
sns.barplot(y = "Average_Cost_for_two", x= "Country", data = data, hue= 'Price_range')
plt.title('Comparison between Average_Cost_for_two and Country ', fontsize=15, fontweight='bold')
plt.show()

# %%
# Observations:

# No such relation between Average_Cost_for_two and Votes.

# Maximum Average_Cost_for_two is for Indonesia (Country_Code=94).

# %%
plt.figure(figsize=(18,5))
sns.scatterplot(y = "Average_Cost_for_two", x= "Longitude", data = data, hue= 'Price_range')
plt.title('Comparison between Average_Cost_for_two and Longitude', fontsize=15, fontweight='bold')
plt.show()

# %%
plt.figure(figsize=(18,5))
sns.scatterplot(y = "Average_Cost_for_two", x= "Latitude", data = data, hue= 'Price_range')
plt.title('Comparison between Average_Cost_for_two and Latitude', fontsize=15, fontweight='bold')
plt.show()

# %%
# Observations:

# No such relation is shown from the above plot between Average_Cost_for_two and Latitude, Longitude.

# %%
plt.figure(figsize=(10,4))
sns.barplot(y = "Average_Cost_for_two", x= "Has_Online_delivery", data = data)
plt.title('Comparison between Average_Cost_for_two and Has_Online_delivery', fontsize=15, fontweight='bold')
plt.show()

# %%
plt.figure(figsize=(10,4))
sns.barplot(y = "Average_Cost_for_two", x= "Is_delivering_now", data = data)
plt.title('Comparison between Average_Cost_for_two and Is_delivering_now', fontsize=15, fontweight='bold')
plt.show()

# %%
# Observations:

# Average_Cost_for_two is high for both Is_delivering_now and Has_Online_delivery equal to No.

# %%
plt.figure(figsize=(10,4))
sns.barplot(y = "Average_Cost_for_two", x= "Rating_color", data = data, hue= 'Price_range')
plt.title('Comparison between Average_Cost_for_two and Rating_color', fontsize=15, fontweight='bold')
plt.show()

# %%
plt.figure(figsize=(10,4))
sns.barplot(y = "Average_Cost_for_two", x= "Rating_text", data = data, hue= 'Price_range')
plt.title('Comparison between Average_Cost_for_two and Rating_text', fontsize=15, fontweight='bold')
plt.show()

# %%
# Observations:

# Average_Cost_for_two is high for Rating_color equal to Green.

# Average_Cost_for_two is high for Rating_text equal to Excellent.

# %% [markdown]
# # Relation with different features and Price_range:

# %%
plt.figure(figsize=(15,5))
sns.barplot(y = "Price_range", x= "Rating_text", data = data)
plt.title('Comparison between Price_range and Rating_text', fontsize=15, fontweight='bold')
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.violinplot(y = "Price_range", x= "Rating_text", data = data)
plt.title('Comparison between Price_range and Rating_text', fontsize=15, fontweight='bold')
plt.show()

# %%
pd.crosstab([data.Price_range],data["Rating_text"],margins=True)
# Out:
# Rating_text  Average  Excellent  Good  Not rated  Poor  Very Good   All
# Price_range
# 1               1898         32   608       1700    62        144  4444
# 2               1425         69   794        402    98        325  3113
# 3                313        126   498         35    20        416  1408
# 4                101         74   200         11     6        194   586
# All             3737        301  2100       2148   186       1079  9551

# %%
# Observations:

# Price_range is high for Excellent Rating_text. It is quite obvious.

# Total 2148 restaurents are not rated.

# Maximum restaurent are Average.

# %%
plt.figure(figsize=(15,5))
sns.boxenplot(y = "Price_range", x= "Rating_color", data = data)
plt.title('Comparison between Price_range and Rating_color', fontsize=15, fontweight='bold')
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.barplot(y = "Price_range", x= "Rating_color", data = data)
plt.title('Comparison between Price_range and Rating_color', fontsize=15, fontweight='bold')
plt.show()

# %%
plt.figure(figsize=(8,4))
sns.scatterplot(y = "Rating_text", x= "Rating_color", data = data)
plt.title('Comparison between Rating_text and Rating_color', fontsize=15, fontweight='bold')
plt.show()

# %%
plt.figure(figsize=(8,4))
sns.violinplot(y = "Price_range", x= "Is_delivering_now", data = data)
plt.title('Comparison between Price_range and Is_delivering_now', fontsize=15, fontweight='bold')
plt.show()

# %%
plt.figure(figsize=(8,4))
sns.barplot(y = "Price_range", x= "Is_delivering_now", data = data)
plt.title('Comparison between Price_range and Is_delivering_now', fontsize=15, fontweight='bold')
plt.show()

# %%
# Observations:

# Maximum Price_range is for Darkgreen color.

# Green stands for Excellent and Red stands for Poor.

# No specific relation is found between Price_range and Is_delivering_now.

# %%
plt.figure(figsize=(8,4))
sns.barplot(y = "Price_range", x= "Has_Online_delivery", data = data)
plt.title('Comparison between Price_range and Has_Online_delivery', fontsize=15, fontweight='bold')
plt.show()

# %%
plt.figure(figsize=(8,4))
sns.boxenplot(y = "Price_range", x= "Has_Table_booking", data = data)
plt.title('Comparison between Price_range and Has_Table_booking', fontsize=15, fontweight='bold')
plt.show()

# %%
# Observations:

# Avg price range is high for Has_Table_booking equal to Yes.

# No specific relation is found between Price_range and Has_Online_delivery.

# %%
plt.figure(figsize=(18,4))
sns.boxenplot(y = "Price_range", x= "Currency", data = data)
plt.title('Comparison between Price_range and Currency', fontsize=15, fontweight='bold')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(18,4))
sns.barplot(y = "Price_range", x= "Currency", data = data)
plt.title('Comparison between Price_range and Currency', fontsize=15, fontweight='bold')
plt.xticks(rotation=90)
plt.show()

# %%
# Observations:

# Price range is low for Indian Rupees(Rs).

# Price range is high for Qatari Rial(QR).

# %%
plt.figure(figsize=(18,4))
sns.boxenplot(y = "Price_range", x= "Aggregate_rating", data = data)
plt.title('Comparison between Price_range and Aggregate_rating', fontsize=15, fontweight='bold')
plt.show()

# %%
plt.figure(figsize=(12,7))
sns.lineplot(y="Price_range", x='Aggregate_rating',data=data)
plt.title('MonthlyCharges Vs Churn', fontsize=20, fontweight='bold')
plt.show()

# %%
plt.figure(figsize=(18,4))
sns.barplot(y = "Price_range", x= "Aggregate_rating", data = data)
plt.title('Comparison between Price_range and Aggregate_rating', fontsize=15, fontweight='bold')
plt.show()

# %%
# Observations:

# If Price_range is high, Aggregate_rating is also high.

# Max price is for 4.8 ratings.

# %%
plt.figure(figsize=(12,4))
sns.boxplot(y = "Latitude", x= "Price_range", data = data)
plt.title('Comparison between Latitude and Price_range', fontsize=15, fontweight='bold')
plt.show()

# %%
plt.figure(figsize=(12,4))
sns.boxenplot(y = "Longitude", x= "Price_range", data = data)
plt.title('Comparison between Longitude and Price_range', fontsize=15, fontweight='bold')
plt.show()

# %%
# Observations:

# No specific relation is found between Latitude, Longitude and Price_range.

# %%
plt.figure(figsize=(12,4))
sns.boxenplot(y = "Votes", x= "Price_range", data = data)
plt.title('Comparison between Votes and Price_range', fontsize=15, fontweight='bold')
plt.show()

# %%
plt.figure(figsize=(12,4))
sns.barplot(y = "Votes", x= "Price_range", data = data)
plt.title('Comparison between Votes and Price_range', fontsize=15, fontweight='bold')
plt.show()

# %%
plt.figure(figsize=(12,4))
sns.boxplot(y = "Country_Code", x= "Price_range", data = data)
plt.title('Comparison between Country_Code and Price_range', fontsize=15, fontweight='bold')
plt.show()

# %%
plt.figure(figsize=(12,4))
sns.boxplot(y = "Country", x= "Price_range", data = data)
plt.title('Comparison between Country and Price_range', fontsize=15, fontweight='bold')
plt.show()

# %%
# Observations:

# Very low votes for Price_range= 1.
# Maximum votes for Price_range= 3.

# %%
sns.pairplot(data,hue="Price_range",palette="tab20_r" )
plt.show()

# %%
# Observation:

# Nothing special relationship are found from the above pairplot.

# %% [markdown]
# # Encoding for categorical features:

# %% [markdown]
# # Using label encoder:

# %%
cat_features= ['Restaurant_Name', 'City', 'Address', 'Locality', 'Locality_Verbose', 'Cuisines', 
             'Currency', 'Has_Table_booking', 'Has_Online_delivery', 'Is_delivering_now', 'Rating_color', 'Rating_text','Country']

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for i in cat_features:
    data[i] = le.fit_transform(data[i])
data.head()
# Out:
#    Restaurant_Name  Country_Code  City  Address  Locality  Locality_Verbose  \
# 0             3749           162    73     8685       171               172
# 1             3173           162    73     6055       593               601
# 2             2897           162    75     4684       308               314
# 3             4707           162    75     8690       862               875
# 4             5523           162    75     8689       862               875
#
#     Longitude   Latitude  Cuisines  Average_Cost_for_two  Currency  \
# 0  121.027535  14.565443       920                  1100         0
# 1  121.014101  14.553708      1111                  1200         0
# 2  121.056831  14.581404      1671                  4000         0
# 3  121.056475  14.585318      1126                  1500         0
# 4  121.057508  14.584450      1122                  1500         0
#
#    Has_Table_booking  Has_Online_delivery  Is_delivering_now  Price_range  \
# 0                  1                    0                  0            3
# 1                  1                    0                  0            3
# 2                  1                    0                  0            4
# 3                  0                    0                  0            4
# 4                  1                    0                  0            4
#
#    Aggregate_rating  Rating_color  Rating_text  Votes  Country
# 0               4.8             0            1    314        6
# 1               4.5             0            1    591        6
# 2               4.4             1            5    270        6
# 3               4.9             0            1    365        6
# 4               4.8             0            1    229        6

# %%
# All categorical features are encoded.

# %% [markdown]
# # Correlation:

# %%
data.corr().T
# Out:
#                       Restaurant_Name  Country_Code      City   Address  \
# Restaurant_Name              1.000000      0.020012 -0.001399  0.000763
# Country_Code                 0.020012      1.000000 -0.181728 -0.220342
# City                        -0.001399     -0.181728  1.000000 -0.019763
# Address                      0.000763     -0.220342 -0.019763  1.000000
# Locality                     0.004322     -0.120075  0.096444  0.159555
# Locality_Verbose             0.004281     -0.117543  0.093142  0.160495
# Longitude                   -0.001920     -0.698299  0.117391  0.185801
# Latitude                     0.009922      0.019792 -0.004301 -0.038654
# Cuisines                     0.051679     -0.132902  0.026614  0.023944
# Average_Cost_for_two         0.019241      0.043225 -0.028838  0.022749
# Currency                     0.009669     -0.033466 -0.071996  0.069499
# Has_Table_booking            0.041173     -0.061682 -0.003762  0.006428
# Has_Online_delivery          0.028082     -0.154605  0.012723  0.029874
# Is_delivering_now            0.011984     -0.018291 -0.014039  0.031267
# Price_range                  0.061275      0.243327 -0.105759 -0.034952
# Aggregate_rating             0.029367      0.282189 -0.132163 -0.151153
# Rating_color                -0.007311     -0.187174  0.110887  0.071264
# Rating_text                  0.012131      0.222685 -0.098985 -0.008029
# Votes                        0.018512      0.154530 -0.078406 -0.101754
# Country                      0.017560      0.968700 -0.180959 -0.235815
#
#                       Locality  Locality_Verbose  Longitude  Latitude  \
# Restaurant_Name       0.004322          0.004281  -0.001920  0.009922
# Country_Code         -0.120075         -0.117543  -0.698299  0.019792
# City                  0.096444          0.093142   0.117391 -0.004301
# Address               0.159555          0.160495   0.185801 -0.038654
# Locality              1.000000          0.999465   0.086448 -0.020424
# Locality_Verbose      0.999465          1.000000   0.084342 -0.020905
# Longitude             0.086448          0.084342   1.000000  0.043207
# Latitude             -0.020424         -0.020905   0.043207  1.000000
# Cuisines              0.006993          0.005960   0.126197  0.038151
# Average_Cost_for_two -0.012136         -0.011852   0.045891 -0.111088
# Currency              0.023723          0.022966   0.337334 -0.101864
# Has_Table_booking    -0.065594         -0.065132   0.100488  0.054658
# Has_Online_delivery  -0.030993         -0.031766   0.178757  0.118722
# Is_delivering_now    -0.007299         -0.007353   0.018787  0.015001
# Price_range          -0.114459         -0.112313  -0.078939 -0.166688
# Aggregate_rating     -0.174336         -0.173254  -0.116818  0.000516
# Rating_color          0.036831          0.037104   0.059979  0.042590
# Rating_text          -0.036969         -0.035430  -0.181466 -0.129447
# Votes                -0.123569         -0.122877  -0.085101 -0.022962
# Country              -0.118784         -0.116406  -0.766221  0.181299
#
#                       Cuisines  Average_Cost_for_two  Currency  \
# Restaurant_Name       0.051679              0.019241  0.009669
# Country_Code         -0.132902              0.043225 -0.033466
# City                  0.026614             -0.028838 -0.071996
# Address               0.023944              0.022749  0.069499
# Locality              0.006993             -0.012136  0.023723
# Locality_Verbose      0.005960             -0.011852  0.022966
# Longitude             0.126197              0.045891  0.337334
# Latitude              0.038151             -0.111088 -0.101864
# Cuisines              1.000000              0.005831  0.068912
# Average_Cost_for_two  0.005831              1.000000  0.045615
# Currency              0.068912              0.045615  1.000000
# Has_Table_booking     0.050639              0.007758  0.000640
# Has_Online_delivery  -0.016639             -0.018974  0.006991
# Is_delivering_now     0.007773             -0.001862  0.001458
# Price_range          -0.005350              0.075083  0.075179
# Aggregate_rating     -0.080331              0.051792 -0.006939
# Rating_color         -0.016228             -0.049970 -0.040430
# Rating_text          -0.079979              0.031439  0.014598
# Votes                -0.032719              0.067783 -0.027111
# Country              -0.127955             -0.004034 -0.105296
#
#                       Has_Table_booking  Has_Online_delivery  \
# Restaurant_Name                0.041173             0.028082
# Country_Code                  -0.061682            -0.154605
# City                          -0.003762             0.012723
# Address                        0.006428             0.029874
# Locality                      -0.065594            -0.030993
# Locality_Verbose              -0.065132            -0.031766
# Longitude                      0.100488             0.178757
# Latitude                       0.054658             0.118722
# Cuisines                       0.050639            -0.016639
# Average_Cost_for_two           0.007758            -0.018974
# Currency                       0.000640             0.006991
# Has_Table_booking              1.000000             0.101224
# Has_Online_delivery            0.101224             1.000000
# Is_delivering_now             -0.016816             0.101730
# Price_range                    0.501925             0.077918
# Aggregate_rating               0.189998             0.225699
# Rating_color                  -0.021365             0.011477
# Rating_text                    0.044043            -0.080937
# Votes                          0.169422             0.074303
# Country                       -0.062076            -0.140464
#
#                       Is_delivering_now  Price_range  Aggregate_rating  \
# Restaurant_Name                0.011984     0.061275          0.029367
# Country_Code                  -0.018291     0.243327          0.282189
# City                          -0.014039    -0.105759         -0.132163
# Address                        0.031267    -0.034952         -0.151153
# Locality                      -0.007299    -0.114459         -0.174336
# Locality_Verbose              -0.007353    -0.112313         -0.173254
# Longitude                      0.018787    -0.078939         -0.116818
# Latitude                       0.015001    -0.166688          0.000516
# Cuisines                       0.007773    -0.005350         -0.080331
# Average_Cost_for_two          -0.001862     0.075083          0.051792
# Currency                       0.001458     0.075179         -0.006939
# Has_Table_booking             -0.016816     0.501925          0.189998
# Has_Online_delivery            0.101730     0.077918          0.225699
# Is_delivering_now              1.000000     0.010940          0.019180
# Price_range                    0.010940     1.000000          0.437944
# Aggregate_rating               0.019180     0.437944          1.000000
# Rating_color                   0.001886    -0.140468         -0.367054
# Rating_text                   -0.031970     0.164242         -0.182662
# Votes                         -0.001124     0.309444          0.313691
# Country                       -0.016607     0.178035          0.255591
#
#                       Rating_color  Rating_text     Votes   Country
# Restaurant_Name          -0.007311     0.012131  0.018512  0.017560
# Country_Code             -0.187174     0.222685  0.154530  0.968700
# City                      0.110887    -0.098985 -0.078406 -0.180959
# Address                   0.071264    -0.008029 -0.101754 -0.235815
# Locality                  0.036831    -0.036969 -0.123569 -0.118784
# Locality_Verbose          0.037104    -0.035430 -0.122877 -0.116406
# Longitude                 0.059979    -0.181466 -0.085101 -0.766221
# Latitude                  0.042590    -0.129447 -0.022962  0.181299
# Cuisines                 -0.016228    -0.079979 -0.032719 -0.127955
# Average_Cost_for_two     -0.049970     0.031439  0.067783 -0.004034
# Currency                 -0.040430     0.014598 -0.027111 -0.105296
# Has_Table_booking        -0.021365     0.044043  0.169422 -0.062076
# Has_Online_delivery       0.011477    -0.080937  0.074303 -0.140464
# Is_delivering_now         0.001886    -0.031970 -0.001124 -0.016607
# Price_range              -0.140468     0.164242  0.309444  0.178035
# Aggregate_rating         -0.367054    -0.182662  0.313691  0.255591
# Rating_color              1.000000     0.163717 -0.169044 -0.155486
# Rating_text               0.163717     1.000000  0.203969  0.203846
# Votes                    -0.169044     0.203969  1.000000  0.155161
# Country                  -0.155486     0.203846  0.155161  1.000000

# %%
plt.subplots(figsize=(20,15))
sns.heatmap(data.corr(), annot= True, linecolor= "yellow",  linewidths= 2)
plt.show()

# %%
data.corr()["Price_range"].sort_values()
# Out:
# Latitude               -0.166688
# Rating_color           -0.140468
# Locality               -0.114459
# Locality_Verbose       -0.112313
# City                   -0.105759
# Longitude              -0.078939
# Address                -0.034952
# Cuisines               -0.005350
# Is_delivering_now       0.010940
# Restaurant_Name         0.061275
# Average_Cost_for_two    0.075083
# Currency                0.075179
# Has_Online_delivery     0.077918
# Rating_text             0.164242
# Country                 0.178035
# Country_Code            0.243327
# Votes                   0.309444
# Aggregate_rating        0.437944
# Has_Table_booking       0.501925
# Price_range             1.000000
# Name: Price_range, dtype: float64

# %%
# we will drop Locality Verbose as it produce multicollinearity

# %%
data.drop(["Locality_Verbose"],axis=1,inplace=True)

# %% [markdown]
# # Removing outliers using Z-score method

# %%
from scipy.stats import zscore
z=np.abs(zscore(data))
np.where(z>3)

dfnew=data[(z<3).all(axis=1)]
dfnew.shape
# Out:
# (8408, 19)

# %%
df['Price range'].value_counts()
# Out:
# 1    4444
# 2    3113
# 3    1408
# 4     586
# Name: Price range, dtype: int64

# %% [markdown]
# # Balancing the data

# %%
from imblearn.over_sampling import SMOTE

# %%
smt=SMOTE()
x=dfnew.drop(["Price_range"],axis=1)
y=dfnew["Price_range"]
train,trainy=smt.fit_resample(x,y)
trainx.shape
# Out:
# (17076, 18)

# %%
trainx.skew().sort_values()
# Out:
# Currency               -10.119308
# Longitude               -3.937290
# Latitude                -3.052929
# Aggregate_rating        -1.471244
# City                    -1.023278
# Cuisines                -0.390373
# Locality                -0.150021
# Address                 -0.145775
# Is_delivering_now        0.000000
# Restaurant_Name          0.003570
# Rating_color             0.142518
# Rating_text              0.502227
# Has_Table_booking        1.162395
# Has_Online_delivery      1.605244
# Average_Cost_for_two     1.758293
# Votes                    2.567558
# Country_Code             9.881002
# Country                 11.894243
# dtype: float64

# %%
list=['Currency','Country_Code','Country']
for i in list:
    if trainx.skew().loc[i]>0.5:
        trainx[i]=np.log1p(trainx[i])
trainx.skew().sort_values()
# Out:
# Currency               -10.119308
# Longitude               -3.937290
# Latitude                -3.052929
# Aggregate_rating        -1.471244
# City                    -1.023278
# Cuisines                -0.390373
# Locality                -0.150021
# Address                 -0.145775
# Is_delivering_now        0.000000
# Restaurant_Name          0.003570
# Rating_color             0.142518
# Rating_text              0.502227
# Has_Table_booking        1.162395
# Has_Online_delivery      1.605244
# Average_Cost_for_two     1.758293
# Votes                    2.567558
# Country_Code             9.590293
# Country                 11.724543
# dtype: float64

# %% [markdown]
# # Standard Scaler

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
x_scale = scaler.fit_transform(trainx)

# %% [markdown]
# # Final predictions using different Classification ML Models for Price_range (target 1) :

# %% [markdown]
# # Find best Random state:

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report,f1_score

from sklearn.linear_model import LogisticRegression

acc_max=0
random_max=0
for i in range(0, 500):
    x_train,x_test,y_train,y_test = train_test_split(x_scale,trainy,test_size = 0.25, random_state=i)
    log= LogisticRegression()
    log.fit(x_train,y_train)
    y_pred=log.predict(x_test)
    acc= accuracy_score(y_test,y_pred)
    if acc>acc_max:
        acc_max=acc
        random_max=i
        
print('Best accuracy is', acc_max ,'on Random_state', random_max)
# Out:
# Best accuracy is 0.9611150152260483 on Random_state 252

# %% [markdown]
# # Here the best accuracy on Random_state=252, Let's take it.

# %%
print('Training feature shape:',x_train.shape)
print('Training target shape:',y_train.shape)
print('Test feature shape:',x_test.shape)
print('Test target shape:',y_test.shape)
# Out:
# Training feature shape: (12807, 18)
# Training target shape: (12807,)
# Test feature shape: (4269, 18)
# Test target shape: (4269,)

# %% [markdown]
# # Using LogisticRegression():

# %%
from sklearn.linear_model import LogisticRegression

x_train,x_test,y_train,y_test = train_test_split(x_scale,trainy,test_size = 0.25, random_state=369)

log = LogisticRegression()

log.fit(x_train, y_train)

y_pred = log.predict(x_test)

print('accu score : ', accuracy_score(y_test, y_pred))
print ('cof_mat:\n ', confusion_matrix(y_test, y_pred))
print('classification report:\n ', classification_report(y_test, y_pred))

print("-----------")
print("-----------")

print('training score : ', log.score(x_train, y_train))
print('testing score : ', log.score(x_test, y_test))
# Out:
# accu score :  0.9538533614429608
# cof_mat:
#   [[1057   23    0    0]
#  [   8 1042   34    0]
#  [   0   30  984   43]
#  [   0    0   59  989]]
# classification report:
#                 precision    recall  f1-score   support
#
#            1       0.99      0.98      0.99      1080
#            2       0.95      0.96      0.96      1084
#            3       0.91      0.93      0.92      1057
#            4       0.96      0.94      0.95      1048
#
#     accuracy                           0.95      4269
#    macro avg       0.95      0.95      0.95      4269
# weighted avg       0.95      0.95      0.95      4269
#
# -----------
# -----------
# training score :  0.9551807605215897
# testing score :  0.9538533614429608

# %% [markdown]
# # Use GridSearchCV for hyperparameter tuning:

# %%
from sklearn.model_selection import GridSearchCV
grid = dict(solver=['newton-cg', 'lbfgs', 'liblinear', 'sag'],penalty=['l2','l1','elasticnet', 'none'], C=[1.0, 0.1,0.01, 0.001]
           , max_iter=[100, 140, 80])

grid_log = GridSearchCV(estimator=log, param_grid= grid, cv=5 )

grid_log.fit(x_train, y_train)
print('best params : ', grid_log.best_params_)
# Out:
# best params :  {'C': 1.0, 'max_iter': 100, 'penalty': 'none', 'solver': 'newton-cg'}

# %%
grid_log_best = grid_log.best_estimator_
grid_log_best.fit(x_train, y_train)

y_pred = grid_log_best.predict(x_test)


print('accu score : ', accuracy_score(y_test, y_pred))
print ('cof_mat:\n\n ', confusion_matrix(y_test, y_pred))
print('classification report:\n ', classification_report(y_test, y_pred))

print("-----------")
print("-----------")

print('training score : ', grid_log_best.score(x_train, y_train))
print('testing score : ', grid_log_best.score(x_test, y_test))
# Out:
# accu score :  0.9571328179901616
# cof_mat:
#
#   [[1070   10    0    0]
#  [  10 1039   35    0]
#  [   0   27  986   44]
#  [   0    0   57  991]]
# classification report:
#                 precision    recall  f1-score   support
#
#            1       0.99      0.99      0.99      1080
#            2       0.97      0.96      0.96      1084
#            3       0.91      0.93      0.92      1057
#            4       0.96      0.95      0.95      1048
#
#     accuracy                           0.96      4269
#    macro avg       0.96      0.96      0.96      4269
# weighted avg       0.96      0.96      0.96      4269
#
# -----------
# -----------
# training score :  0.9595533692511907
# testing score :  0.9571328179901616

# %%
# Observations:

# Accuracy score is improved after using gridsearchCV .

# %% [markdown]
# # Using DecisionTreeClassifier()

# %%
from sklearn.tree import DecisionTreeClassifier

clf = DecisionTreeClassifier()
clf.fit(x_train, y_train)

y_pred = clf.predict(x_test)


print('accu score : ', accuracy_score(y_test, y_pred))
print("\n")
print ('cof_mat: ', confusion_matrix(y_test, y_pred))
print("\n")
print('classification report: \n\n', classification_report(y_test, y_pred))

print("-----------")
print("-----------")

print('training score : ', clf.score(x_train, y_train))
print('testing score : ', clf.score(x_test, y_test))
# Out:
# accu score :  0.9859451862262825
#
#
# cof_mat:  [[1073    7    0    0]
#  [   3 1067   14    0]
#  [   0   14 1033   10]
#  [   0    0   12 1036]]
#
#
# classification report:
#
#                precision    recall  f1-score   support
#
#            1       1.00      0.99      1.00      1080
#            2       0.98      0.98      0.98      1084
#            3       0.98      0.98      0.98      1057
#            4       0.99      0.99      0.99      1048
#
#     accuracy                           0.99      4269
#    macro avg       0.99      0.99      0.99      4269
# weighted avg       0.99      0.99      0.99      4269
#
# -----------
# -----------
# training score :  1.0
# testing score :  0.9859451862262825

# %% [markdown]
# # Use GridSearchCV for hyperparameter tuning:

# %%
param = {'criterion' : ['gini', 'entropy'], 'splitter': ["best", "random"], 'ccp_alpha': [0.1, .01, 0.001],
        'max_features': ['auto', 'sqrt', 'log2']}

grid_search = GridSearchCV(estimator = clf, cv=5, param_grid = param)

grid_search.fit(x_train, y_train)
print('best params : ', grid_search.best_params_)
# Out:
# best params :  {'ccp_alpha': 0.001, 'criterion': 'entropy', 'max_features': 'log2', 'splitter': 'best'}

# %%
grid_clf_best = grid_search.best_estimator_
grid_clf_best.fit(x_train, y_train)

y_pred = grid_clf_best.predict(x_test)

print('accu score : ', accuracy_score(y_test, y_pred))
print("\n")
print ('cof_mat: ', confusion_matrix(y_test, y_pred))
print("\n")
print('classification report: \n\n', classification_report(y_test, y_pred))

print("-----------")
print("-----------")


print('training score : ', grid_clf_best.score(x_train, y_train))
print('testing score : ', grid_clf_best.score(x_test, y_test))
# Out:
# accu score :  0.9505739048957601
#
#
# cof_mat:  [[1070    6    2    2]
#  [   3 1029   42   10]
#  [   0   20  962   75]
#  [   1    0   50  997]]
#
#
# classification report:
#
#                precision    recall  f1-score   support
#
#            1       1.00      0.99      0.99      1080
#            2       0.98      0.95      0.96      1084
#            3       0.91      0.91      0.91      1057
#            4       0.92      0.95      0.94      1048
#
#     accuracy                           0.95      4269
#    macro avg       0.95      0.95      0.95      4269
# weighted avg       0.95      0.95      0.95      4269
#
# -----------
# -----------
# training score :  0.9604122745373623
# testing score :  0.9505739048957601

# %%
# Observations:

# Accuracy score is not improved after using GridSearchCV with DecisionTreeClassifier().

# But the difference between training score, testing score is decreased.

# %% [markdown]
# # Using GradientBoostingClassifier():

# %%
from sklearn.ensemble import GradientBoostingClassifier

gbdt= GradientBoostingClassifier()
gbdt.fit(x_train, y_train)

y_pred = gbdt.predict(x_test)


print('accu score : ', accuracy_score(y_test, y_pred))
print("\n")
print ('cof_mat: ', confusion_matrix(y_test, y_pred))
print("\n")
print('classification report: \n\n', classification_report(y_test, y_pred))

print("-----------")
print("-----------")

print('training score : ', gbdt.score(x_train, y_train))
print('testing score : ', gbdt.score(x_test, y_test))
# Out:
# accu score :  0.9873506676036542
#
#
# cof_mat:  [[1078    2    0    0]
#  [   4 1076    4    0]
#  [   0   21 1030    6]
#  [   0    0   17 1031]]
#
#
# classification report:
#
#                precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00      1080
#            2       0.98      0.99      0.99      1084
#            3       0.98      0.97      0.98      1057
#            4       0.99      0.98      0.99      1048
#
#     accuracy                           0.99      4269
#    macro avg       0.99      0.99      0.99      4269
# weighted avg       0.99      0.99      0.99      4269
#
# -----------
# -----------
# training score :  0.994378074490513
# testing score :  0.9873506676036542

# %% [markdown]
# # Using Gridsearch CV:

# %%
param= {"min_samples_split" : [2,3],"learning_rate": [0.1,0.01], 
        "criterion":['friedman_mse', 'squared_error'] }

grid_gbdt= GridSearchCV (gbdt, param_grid= param,cv=5)

grid_gbdt.fit(x_train, y_train)
print('best params : ', grid_gbdt.best_params_)
# Out:
# best params :  {'criterion': 'friedman_mse', 'learning_rate': 0.1, 'min_samples_split': 2}

# %%
grid_gbdt_best = grid_gbdt.best_estimator_
grid_gbdt_best.fit(x_train, y_train)

y_pred = grid_gbdt_best.predict(x_test)

print('accu score : ', accuracy_score(y_test, y_pred))
print("\n")
print ('cof_mat: ', confusion_matrix(y_test, y_pred))
print("\n")
print('classification report:\n\n ', classification_report(y_test, y_pred))

print("-----------")
print("-----------")


print('training score : ', grid_gbdt_best.score(x_train, y_train))
print('testing score : ', grid_gbdt_best.score(x_test, y_test))
# Out:
# accu score :  0.9873506676036542
#
#
# cof_mat:  [[1078    2    0    0]
#  [   4 1076    4    0]
#  [   0   21 1030    6]
#  [   0    0   17 1031]]
#
#
# classification report:
#
#                 precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00      1080
#            2       0.98      0.99      0.99      1084
#            3       0.98      0.97      0.98      1057
#            4       0.99      0.98      0.99      1048
#
#     accuracy                           0.99      4269
#    macro avg       0.99      0.99      0.99      4269
# weighted avg       0.99      0.99      0.99      4269
#
# -----------
# -----------
# training score :  0.994378074490513
# testing score :  0.9873506676036542

# %%
# Observations:


# Accuracy score, training score, testing score are not improved after using GridSearchCV with GradientBoostingClassifier()

# %% [markdown]
# # Using RandomForestClassifier()

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()
rf.fit(x_train, y_train)

y_pred = rf.predict(x_test)


print('accu score : ', accuracy_score(y_test, y_pred))
print("\n")
print ('cof_mat: ', confusion_matrix(y_test, y_pred))
print("\n")
print('classification report: ', classification_report(y_test, y_pred))

print("-----------")
print("-----------")

print('training score : ', rf.score(x_train, y_train))
print('testing score : ', rf.score(x_test, y_test))
# Out:
# accu score :  0.9955493089716562
#
#
# cof_mat:  [[1077    3    0    0]
#  [   2 1081    1    0]
#  [   0    6 1048    3]
#  [   0    0    4 1044]]
#
#
# classification report:                precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00      1080
#            2       0.99      1.00      0.99      1084
#            3       1.00      0.99      0.99      1057
#            4       1.00      1.00      1.00      1048
#
#     accuracy                           1.00      4269
#    macro avg       1.00      1.00      1.00      4269
# weighted avg       1.00      1.00      1.00      4269
#
# -----------
# -----------
# training score :  1.0
# testing score :  0.9955493089716562

# %% [markdown]
# # Use GridSearchCV for hyperparameter tuning:

# %%
params = {'n_estimators' : [100,80, 150], 'min_samples_leaf': [1,2,3],
          'criterion' : ["gini", "entropy"]}

rf_grd = GridSearchCV(rf, param_grid = params, cv=5)

rf_grd.fit(x_train, y_train)
print('best params : ', rf_grd.best_params_)
# Out:
# best params :  {'criterion': 'entropy', 'min_samples_leaf': 1, 'n_estimators': 150}

# %%
grid_rf_best = rf_grd.best_estimator_

grid_rf_best.fit(x_train, y_train)

y_pred = grid_rf_best.predict(x_test)

print('accu score : ', accuracy_score(y_test, y_pred))
print("\n")
print ('cof_mat: ', confusion_matrix(y_test, y_pred))
print("\n")
print('classification report: \n', classification_report(y_test, y_pred))

print("-----------")
print("-----------")


print('training score : ', grid_rf_best.score(x_train, y_train))
print('testing score : ', grid_rf_best.score(x_test, y_test))
# Out:
# accu score :  0.9964862965565706
#
#
# cof_mat:  [[1076    4    0    0]
#  [   1 1082    1    0]
#  [   0    4 1051    2]
#  [   0    0    3 1045]]
#
#
# classification report:
#                precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00      1080
#            2       0.99      1.00      1.00      1084
#            3       1.00      0.99      1.00      1057
#            4       1.00      1.00      1.00      1048
#
#     accuracy                           1.00      4269
#    macro avg       1.00      1.00      1.00      4269
# weighted avg       1.00      1.00      1.00      4269
#
# -----------
# -----------
# training score :  1.0
# testing score :  0.9964862965565706

# %%
# Observations:


# Accuracy score is slightly improved after using GridSearchCV with RandomForestClassifier()

# %% [markdown]
# # ExtraTreesClassifier():

# %%
from sklearn.ensemble import ExtraTreesClassifier

etc =ExtraTreesClassifier()
etc.fit(x_train, y_train)

y_pred = etc.predict(x_test)


print('accu score : ', accuracy_score(y_test, y_pred))
print("\n")
print ('cof_mat: ', confusion_matrix(y_test, y_pred))
print("\n")
print('classification report: ', classification_report(y_test, y_pred))

print("-----------")
print("-----------")

print('training score : ', etc.score(x_train, y_train))
print('testing score : ', etc.score(x_test, y_test))
# Out:
# accu score :  0.985008198641368
#
#
# cof_mat:  [[1066   14    0    0]
#  [   4 1055   25    0]
#  [   0    4 1045    8]
#  [   0    0    9 1039]]
#
#
# classification report:                precision    recall  f1-score   support
#
#            1       1.00      0.99      0.99      1080
#            2       0.98      0.97      0.98      1084
#            3       0.97      0.99      0.98      1057
#            4       0.99      0.99      0.99      1048
#
#     accuracy                           0.99      4269
#    macro avg       0.99      0.99      0.99      4269
# weighted avg       0.99      0.99      0.99      4269
#
# -----------
# -----------
# training score :  1.0
# testing score :  0.985008198641368

# %% [markdown]
# # Use GridSearchCV for hyperparameter tuning:

# %%
params = {'n_estimators' : [100,80, 150], 'min_samples_leaf': [1,2],
          'criterion' : ["gini", "entropy"]}

etc_grd = GridSearchCV(etc, param_grid = params, cv=5)

etc_grd.fit(x_train, y_train)
print('best params : ', etc_grd.best_params_)
# Out:
# best params :  {'criterion': 'gini', 'min_samples_leaf': 1, 'n_estimators': 150}

# %%
grid_etc_best = etc_grd.best_estimator_
grid_etc_best.fit(x_train, y_train)

y_pred = grid_etc_best.predict(x_test)

print('accu score : ', accuracy_score(y_test, y_pred))
print("\n")
print ('cof_mat: ', confusion_matrix(y_test, y_pred))
print("\n")
print('classification report: \n', classification_report(y_test, y_pred))

print("-----------")
print("-----------")


print('training score : ', grid_etc_best.score(x_train, y_train))
print('testing score : ', grid_etc_best.score(x_test, y_test))
# Out:
# accu score :  0.9866479269149684
#
#
# cof_mat:  [[1064   15    1    0]
#  [   2 1060   22    0]
#  [   0    6 1048    3]
#  [   0    0    8 1040]]
#
#
# classification report:
#                precision    recall  f1-score   support
#
#            1       1.00      0.99      0.99      1080
#            2       0.98      0.98      0.98      1084
#            3       0.97      0.99      0.98      1057
#            4       1.00      0.99      0.99      1048
#
#     accuracy                           0.99      4269
#    macro avg       0.99      0.99      0.99      4269
# weighted avg       0.99      0.99      0.99      4269
#
# -----------
# -----------
# training score :  1.0
# testing score :  0.9866479269149684

# %%
# Observations:

# Accuracy score is slightly improved after using GridSearchCV with ExtraTreesClassifier()

# %% [markdown]
# # Using AdaBoostClassifier:

# %%
from sklearn.ensemble import AdaBoostClassifier

ada = AdaBoostClassifier()
ada.fit(x_train, y_train)

y_pred = ada.predict(x_test)


print('accu score : ', accuracy_score(y_test, y_pred))
print("\n")
print ('cof_mat: ', confusion_matrix(y_test, y_pred))
print("\n")
print('classification report: ', classification_report(y_test, y_pred))

print("-----------")
print("-----------")

print('training score : ', ada.score(x_train, y_train))
print('testing score : ', ada.score(x_test, y_test))
# Out:
# accu score :  0.5090185055048021
#
#
# cof_mat:  [[1080    0    0    0]
#  [  15 1069    0    0]
#  [   0 1055    0    2]
#  [   0 1017    7   24]]
#
#
# classification report:                precision    recall  f1-score   support
#
#            1       0.99      1.00      0.99      1080
#            2       0.34      0.99      0.51      1084
#            3       0.00      0.00      0.00      1057
#            4       0.92      0.02      0.04      1048
#
#     accuracy                           0.51      4269
#    macro avg       0.56      0.50      0.39      4269
# weighted avg       0.56      0.51      0.39      4269
#
# -----------
# -----------
# training score :  0.4976184898883423
# testing score :  0.5090185055048021

# %% [markdown]
# # Using GridSearchCV for hyperparameter tuning:

# %%
params = {'n_estimators' : [50,40, 60, 45], 'learning_rate': [1,0.1,0.01, 0.001] }

ada_grd = GridSearchCV(ada, param_grid = params, cv=5)

ada_grd.fit(x_train, y_train)
print('best params : ', ada_grd.best_params_)
# Out:
# best params :  {'learning_rate': 1, 'n_estimators': 50}

# %%
grid_ada_best = ada_grd.best_estimator_
grid_ada_best.fit(x_train, y_train)

y_pred = grid_ada_best.predict(x_test)

print('accu score : ', accuracy_score(y_test, y_pred))
print("\n")
print ('cof_mat: ', confusion_matrix(y_test, y_pred))
print("\n")
print('classification report: \n', classification_report(y_test, y_pred))

print("-----------")
print("-----------")


print('training score : ', grid_ada_best.score(x_train, y_train))
print('testing score : ', grid_ada_best.score(x_test, y_test))
# Out:
# accu score :  0.5090185055048021
#
#
# cof_mat:  [[1080    0    0    0]
#  [  15 1069    0    0]
#  [   0 1055    0    2]
#  [   0 1017    7   24]]
#
#
# classification report:
#                precision    recall  f1-score   support
#
#            1       0.99      1.00      0.99      1080
#            2       0.34      0.99      0.51      1084
#            3       0.00      0.00      0.00      1057
#            4       0.92      0.02      0.04      1048
#
#     accuracy                           0.51      4269
#    macro avg       0.56      0.50      0.39      4269
# weighted avg       0.56      0.51      0.39      4269
#
# -----------
# -----------
# training score :  0.4976184898883423
# testing score :  0.5090185055048021

# %%
# Observations:

# Accuracy score is not improved after using GridSearchCV with AdaBoostClassifier().

# %% [markdown]
# # Using SVC('rbf'):

# %%
from sklearn.svm import SVC
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA

def svmkernel(ker):
    #svc = SVC(kernel = ker )
    pipe = Pipeline([('PCA', PCA()),
                ('SVM', SVC(C=7, gamma=0.01, kernel = ker))])
    
    pipe.fit(x_train, y_train)
    pipe.score(x_train, y_train)
    predsvc = pipe.predict(x_test)
    print('accu score : ', accuracy_score(y_test, predsvc))
    print("\n")
    print ('cof_mat: ', confusion_matrix(y_test, predsvc))
    print("\n")
    print('classification report: \n\n', classification_report(y_test, predsvc))
    
    print("-----------")
    print("-----------")
    
    
    print('training score : ', pipe.score(x_train, y_train))
    print('testing score : ', pipe.score(x_test, y_test))

# %%
svmkernel('rbf')
# Out:
# accu score :  0.9615835090185055
#
#
# cof_mat:  [[1046   34    0    0]
#  [  14 1040   30    0]
#  [   0   23 1006   28]
#  [   0    0   35 1013]]
#
#
# classification report:
#
#                precision    recall  f1-score   support
#
#            1       0.99      0.97      0.98      1080
#            2       0.95      0.96      0.95      1084
#            3       0.94      0.95      0.95      1057
#            4       0.97      0.97      0.97      1048
#
#     accuracy                           0.96      4269
#    macro avg       0.96      0.96      0.96      4269
# weighted avg       0.96      0.96      0.96      4269
#
# -----------
# -----------
# training score :  0.966893105333021
# testing score :  0.9615835090185055

# %% [markdown]
# # Using SVC ('linear'):

# %%
svmkernel('linear')
# Out:
# accu score :  0.9599437807449052
#
#
# cof_mat:  [[1076    4    0    0]
#  [  10 1040   34    0]
#  [   0   29  991   37]
#  [   0    0   57  991]]
#
#
# classification report:
#
#                precision    recall  f1-score   support
#
#            1       0.99      1.00      0.99      1080
#            2       0.97      0.96      0.96      1084
#            3       0.92      0.94      0.93      1057
#            4       0.96      0.95      0.95      1048
#
#     accuracy                           0.96      4269
#    macro avg       0.96      0.96      0.96      4269
# weighted avg       0.96      0.96      0.96      4269
#
# -----------
# -----------
# training score :  0.9596314515499337
# testing score :  0.9599437807449052

# %% [markdown]
# # Using SVC ('poly'):

# %%
svmkernel('poly')
# Out:
# accu score :  0.6141953619114546
#
#
# cof_mat:  [[440 619  21   0]
#  [133 846 105   0]
#  [  2 266 780   9]
#  [  0  20 472 556]]
#
#
# classification report:
#
#                precision    recall  f1-score   support
#
#            1       0.77      0.41      0.53      1080
#            2       0.48      0.78      0.60      1084
#            3       0.57      0.74      0.64      1057
#            4       0.98      0.53      0.69      1048
#
#     accuracy                           0.61      4269
#    macro avg       0.70      0.61      0.61      4269
# weighted avg       0.70      0.61      0.61      4269
#
# -----------
# -----------
# training score :  0.6209104396033419
# testing score :  0.6141953619114546

# %%
# Observation:
# SVC(''rbf') is better than two others. let's take it for further process.

# %% [markdown]
# # Here, RandomForestclassifier(), Gradient BoostClassifier() and Extra Tree Classifiers () gives the best accuracy score. Let's check CV with the hyper tunned model of respective ML model.

# %% [markdown]
# # Cross Validtion:

# %%
from sklearn.model_selection import cross_val_score
svm_best = Pipeline([('PCA', PCA()),
                ('SVM', SVC(C=7, gamma=0.01, kernel = "linear"))])

all_models = [grid_log_best, clf, gbdt, grid_rf_best, grid_etc_best, grid_ada_best, svm_best ]

for i in all_models:
    cvscore = cross_val_score(i, x_scale,trainy, cv =7)
    print('Cross Validation Score of :',i)
    print("\n Cross Validation Score : " ,cvscore)
    print("\nMean CV Score :",cvscore.mean())
    print("\nStd deviation :",cvscore.std())
    print("\n-----------")
    print("-----------")
# Out:
# Cross Validation Score of : LogisticRegression(penalty='none', solver='newton-cg')
#
#  Cross Validation Score :  [0.9352459  0.94385246 0.96270492 0.96391964 0.96596966 0.96063961
#  0.96432964]
#
# Mean CV Score : 0.9566659753248585
#
# Std deviation : 0.011168644367338068
#
# -----------
# -----------
# Cross Validation Score of : DecisionTreeClassifier()
#
#  Cross Validation Score :  [0.975      0.97540984 0.98688525 0.98687987 0.97703977 0.98851989
#  0.97826978]
#
# Mean CV Score : 0.9811434841514692
#
# Std deviation : 0.005554933119542726
#
# -----------
# -----------
# Cross Validation Score of : GradientBoostingClassifier()
#
#  Cross Validation Score :  [0.97254098 0.97786885 0.98688525 0.9901599  0.97211972 0.99056991
#  0.98400984]
#
# Mean CV Score : 0.9820220643658428
#
# Std deviation : 0.007290779255244361
#
# -----------
# -----------
# Cross Validation Score of : RandomForestClassifier(criterion='entropy', n_estimators=150)
#
#  Cross Validation Score :  [0.96803279 0.98442623 0.99508197 0.99589996 0.98441984 0.99753998
#  0.9897499 ]
#
# Mean CV Score : 0.9878786656719027
#
# Std deviation : 0.009492950619237448
#
# -----------
# -----------
# Cross Validation Score of : ExtraTreesClassifier(n_estimators=150)
#
#  Cross Validation Score :  [0.82663934 0.95409836 0.97008197 0.98441984 0.96678967 0.98769988
#  0.9401394 ]
#
# Mean CV Score : 0.947124066088436
#
# Std deviation : 0.05149919157967492
#
# -----------
# -----------
# Cross Validation Score of : AdaBoostClassifier(learning_rate=1)
#
#  Cross Validation Score :  [0.65040984 0.49672131 0.5045082  0.50307503 0.49774498 0.50184502
#  0.50102501]
#
# Mean CV Score : 0.5221899115946662
#
# Std deviation : 0.0524083456620768
#
# -----------
# -----------
# Cross Validation Score of : Pipeline(steps=[('PCA', PCA()), ('SVM', SVC(C=7, gamma=0.01, kernel='linear'))])
#
#  Cross Validation Score :  [0.93852459 0.94754098 0.9647541  0.96555966 0.96309963 0.96063961
#  0.96637966]
#
# Mean CV Score : 0.9580711755595307
#
# Std deviation : 0.009961396283743163
#
# -----------
# -----------

# %% [markdown]
# # Among 7 classification models RandomForestClassifier() gives good accuracy and maximum f1 score along with a good Cross-validation score.

# %%
y_pred = grid_rf_best.predict(x_test)
y_pred
# Out:
# array([2, 3, 2, ..., 1, 4, 3])

# %%
y_prob = grid_rf_best.predict_proba(x_test)
from sklearn.metrics import roc_auc_score

macro_ovo = roc_auc_score(y_test, y_prob, multi_class="ovo", average="macro")

macro_ovr = roc_auc_score(y_test, y_prob, multi_class="ovr", average="macro")


print("One-Vs-One AUC ROC Sore: ", macro_ovo, "when avg = macro")
print("==========================")
print("One-Vs-Rest AUC ROC Sore: ", macro_ovr, "when avg = macro")
# Out:
# One-Vs-One AUC ROC Sore:  0.9999525916098427 when avg = macro
# ==========================
# One-Vs-Rest AUC ROC Sore:  0.999952845649553 when avg = macro

# %%
from sklearn import metrics
class_names = data.columns
metrics.plot_confusion_matrix(grid_rf_best, x_test, y_test)
plt.title('Confusion Matrix \n')
plt.show()

# %% [markdown]
# # Load and save the model

# %%
# Now , let's save the model for future use.

# %%
import pickle
pickle.dump(grid_rf_best, open("Zomato_Price_range_Classification_model", "wb"))
load_Zomato_Price_range_Classification_model= pickle.load(open("Zomato_Price_range_Classification_model", "rb"))

# %%
y_pred = load_Zomato_Price_range_Classification_model.predict(x_test)

y_test = np.array(y_test)
data_prediction_by_model = pd.DataFrame()
data_prediction_by_model["Predicted Values"] = y_pred
data_prediction_by_model["Actual Values"] = y_test
data_prediction_by_model.sample(n= 8)
# Out:
#       Predicted Values  Actual Values
# 2060                 2              2
# 893                  3              3
# 1560                 4              4
# 1985                 2              2
# 934                  2              2
# 3129                 4              4
# 361                  1              1
# 2709                 2              2

# %% [markdown]
# # Predicting the average cost for two(Target 2)

# %%
# Checking skewness of data


dfnew.skew().sort_values()
# Out:
# Currency               -18.026851
# Longitude               -3.702347
# Latitude                -3.241005
# City                    -1.392152
# Aggregate_rating        -0.861415
# Cuisines                -0.345840
# Locality                -0.316614
# Address                 -0.121484
# Is_delivering_now        0.000000
# Restaurant_Name          0.045448
# Rating_color             0.101035
# Rating_text              0.422542
# Has_Online_delivery      1.001452
# Price_range              1.054225
# Has_Table_booking        2.269837
# Average_Cost_for_two     3.716607
# Votes                    3.730394
# Country_Code            19.985320
# Country                 20.254626
# dtype: float64

# %%
trainx=dfnew.drop(['Average_Cost_for_two'],axis=1)
y=dfnew["Average_Cost_for_two"]

# %%
list=['Is_delivering_now','Country_Code','Country','Votes','Has_Table_booking']
for i in list:
    if trainx.skew().loc[i]>0.5:
        trainx[i]=np.log1p(trainx[i])

# %%
trainx.skew()
# Out:
# Restaurant_Name         0.045448
# Country_Code           19.941082
# City                   -1.392152
# Address                -0.121484
# Locality               -0.316614
# Longitude              -3.702347
# Latitude               -3.241005
# Cuisines               -0.345840
# Currency              -18.026851
# Has_Table_booking       2.269837
# Has_Online_delivery     1.001452
# Is_delivering_now       0.000000
# Price_range             1.054225
# Aggregate_rating       -0.861415
# Rating_color            0.101035
# Rating_text             0.422542
# Votes                  -0.034100
# Country                20.180374
# dtype: float64

# %% [markdown]
# # Standard scaler

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
x_scale = scaler.fit_transform(trainx)

# %% [markdown]
# # Find best Random state:

# %%
from sklearn.linear_model import LinearRegression

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

r2_max=0
random_max=0
for i in range(500,2000):
    x_train,x_test,y_train,y_test = train_test_split(x_scale,y,test_size = 0.25, random_state=i)
    lin_reg= LinearRegression()
    
    lin_reg.fit(x_train,y_train)
    y_pred=lin_reg.predict(x_test)
    r2 = r2_score(y_test,y_pred)
    
    if r2>r2_max:
        r2_max=r2
        random_max=i
print('Best accuracy is', r2_max ,'on Random_state', random_max)
# Out:
# Best accuracy is 0.802329944719504 on Random_state 1139

# %%
print('Training feature shape:',x_train.shape)
print('Training target shape:',y_train.shape)
print('Test feature shape:',x_test.shape)
print('Test target shape:',y_test.shape)
# Out:
# Training feature shape: (6306, 18)
# Training target shape: (6306,)
# Test feature shape: (2102, 18)
# Test target shape: (2102,)

# %% [markdown]
# # For random state=1139, the accuracy score is best. Lets take this random state for further steps.

# %% [markdown]
# # Using LinearRegression()

# %%
x_train,x_test,y_train,y_test = train_test_split(x_scale,y,test_size = 0.25, random_state=1500 )

lin_reg= LinearRegression()

lin_reg.fit(x_train, y_train)

y_pred = lin_reg.predict(x_test)

print('R2 Score:', r2_score(y_test, y_pred))
print('Mean absolute error:', mean_absolute_error(y_test, y_pred))
print('Mean square error:', mean_squared_error(y_test, y_pred))
print('Root mean square error:',np.sqrt( mean_squared_error(y_test, y_pred)))
# Out:
# R2 Score: 0.7260404359528931
# Mean absolute error: 171.94774933348455
# Mean square error: 99107.22671096836
# Root mean square error: 314.81300276667156

# %% [markdown]
# # Using GridSearchCV:

# %%
from sklearn.model_selection import GridSearchCV

grid = dict(fit_intercept=['True', 'False'], n_jobs=[1,-1])

grid_lin = GridSearchCV(estimator=lin_reg, param_grid= grid, cv=9)

grid_lin.fit(x_train, y_train)
grid_lin.best_params_
# Out:
# {'fit_intercept': 'True', 'n_jobs': 1}

# %%
grid_lin_best = LinearRegression(fit_intercept= 'True', n_jobs= 1)

grid_lin_best.fit(x_train, y_train)
y_pred = grid_lin_best.predict(x_test)

print('R2 Score:', r2_score(y_test, y_pred))
print('Mean absolute error:', mean_absolute_error(y_test, y_pred))
print('Mean square error:', mean_squared_error(y_test, y_pred))
print('Root mean square error:',np.sqrt( mean_squared_error(y_test, y_pred)))
# Out:
# R2 Score: 0.7260404359528931
# Mean absolute error: 171.94774933348455
# Mean square error: 99107.22671096836
# Root mean square error: 314.81300276667156

# %%
# Observations:
#No such improvement seen after GridSearchCV.

# %% [markdown]
# # Using DecisionTreeRegressor():

# %%
from sklearn.tree import DecisionTreeRegressor

dt = DecisionTreeRegressor()
dt.fit(x_train, y_train)

y_pred = dt.predict(x_test)

print('R2 Score:', r2_score(y_test, y_pred))
print('Mean absolute error:', mean_absolute_error(y_test, y_pred))
print('Mean square error:', mean_squared_error(y_test, y_pred))
print('Root mean square error:',np.sqrt( mean_squared_error(y_test, y_pred)))
# Out:
# R2 Score: 0.6794962967287448
# Mean absolute error: 143.3943862987631
# Mean square error: 115944.96907706946
# Root mean square error: 340.5069295580774

# %% [markdown]
# # Using GridSearchCV:

# %%
param = {'criterion' : ["squared_error", "friedman_mse", "absolute_error"],
    'min_samples_split' : range(1,4),
    'splitter' : ["best", "random"],
    'min_samples_leaf' : range(1,3)}

grid_search = GridSearchCV(estimator = dt,cv=5,param_grid = param)
grid_search.fit(x_train, y_train)

print("Best Parameters:" , grid_search.best_params_)
# Out:
# Best Parameters: {'criterion': 'squared_error', 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'random'}

# %%
grid_dt_best = grid_search.best_estimator_
grid_dt_best.fit(x_train, y_train)

y_pred = grid_dt_best.predict(x_test)

print('R2 Score:', r2_score(y_test, y_pred))
print('Mean absolute error:', mean_absolute_error(y_test, y_pred))
print('Mean square error:', mean_squared_error(y_test, y_pred))
print('Root mean square error:',np.sqrt( mean_squared_error(y_test, y_pred)))
# Out:
# R2 Score: 0.8211706070593107
# Mean absolute error: 131.98818585474152
# Mean square error: 64693.06976160271
# Root mean square error: 254.34832368545838

# %%
# Observations:

#Scores have improved

# %% [markdown]
# # Using KNeighborsRegressor():

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn import neighbors
rmse_val = []
for i in range(0,20):
    i = i+1
    knn = neighbors.KNeighborsRegressor(n_neighbors = i)

    knn.fit(x_train,y_train) 
    y_pred=knn.predict(x_test) 
    error =np. sqrt(mean_squared_error(y_test,y_pred)) 
    rmse_val.append(error) 
    print('RMSE value for k= ' , i , 'is:', error)
# Out:
# RMSE value for k=  1 is: 327.8297179591329
# RMSE value for k=  2 is: 290.86893875726463
# RMSE value for k=  3 is: 285.5356447990121
# RMSE value for k=  4 is: 286.40201512240634
# RMSE value for k=  5 is: 285.09381749943896
# RMSE value for k=  6 is: 281.6789064341707
# RMSE value for k=  7 is: 283.5194149533818
# RMSE value for k=  8 is: 286.19765338857354
# RMSE value for k=  9 is: 283.21026552432977
# RMSE value for k=  10 is: 279.4859683733734
# RMSE value for k=  11 is: 277.5533231754411
# RMSE value for k=  12 is: 275.5272505610827
# RMSE value for k=  13 is: 276.1602224597641
# RMSE value for k=  14 is: 276.8930385784378
# RMSE value for k=  15 is: 278.02640150614104
# RMSE value for k=  16 is: 280.2435545144117
# RMSE value for k=  17 is: 282.9954156324752
# RMSE value for k=  18 is: 286.2485369607924
# RMSE value for k=  19 is: 288.0738260445045
# RMSE value for k=  20 is: 289.57996316493177

# %%
min(rmse_val)
# Out:
# 275.5272505610827

# %% [markdown]
# # For k=12 we get the best RMSE value for KNeighborsRegressor()

# %%
knn =KNeighborsRegressor(n_neighbors= 12)
knn.fit(x_train, y_train)

y_pred = knn.predict(x_test)

print('R2 Score:', r2_score(y_test, y_pred))
print('Mean absolute error:', mean_absolute_error(y_test, y_pred))
print('Mean square error:', mean_squared_error(y_test, y_pred))
print('Root mean square error:',np.sqrt( mean_squared_error(y_test, y_pred)))
# Out:
# R2 Score: 0.7901493784684235
# Mean absolute error: 151.2517840152236
# Mean square error: 75915.26580174966
# Root mean square error: 275.5272505610827

# %% [markdown]
# # Using GridSearchCV

# %%
param = {'algorithm' : ['auto', 'ball_tree', 'kd_tree'],
             'leaf_size' : [30,40,25],
             'n_neighbors' : [13],'weights': ['uniform', 'distance']}
    

gridsearchknn = GridSearchCV(estimator = knn, param_grid=param, cv=5)

gridsearchknn.fit(x_train, y_train) 

print("Best Parameters:" , gridsearchknn.best_params_)
# Out:
# Best Parameters: {'algorithm': 'auto', 'leaf_size': 30, 'n_neighbors': 13, 'weights': 'distance'}

# %%
grid_knn_best = gridsearchknn.best_estimator_

grid_knn_best.fit(x_train, y_train)

y_pred = grid_knn_best.predict(x_test)

print('R2 Score:', r2_score(y_test, y_pred))
print('Mean absolute error:', mean_absolute_error(y_test, y_pred))
print('Mean square error:', mean_squared_error(y_test, y_pred))
print('Root mean square error:',np.sqrt( mean_squared_error(y_test, y_pred)))
# Out:
# R2 Score: 0.79698470586706
# Mean absolute error: 148.03084481977575
# Mean square error: 73442.52737227878
# Root mean square error: 271.00281801538296

# %%
# Observation

# Slight improvement in the scores

# %% [markdown]
# # Using RandomForestRegressor():

# %%
from sklearn.ensemble import RandomForestRegressor

rf= RandomForestRegressor()
rf.fit(x_train, y_train)

y_pred = rf.predict(x_test)

print('R2 Score:', r2_score(y_test, y_pred))
print('Mean absolute error:', mean_absolute_error(y_test, y_pred))
print('Mean square error:', mean_squared_error(y_test, y_pred))
print('Root mean square error:',np.sqrt( mean_squared_error(y_test, y_pred)))
# Out:
# R2 Score: 0.8723455073643314
# Mean absolute error: 105.08494291151284
# Mean square error: 46180.10977759277
# Root mean square error: 214.89557877628096

# %% [markdown]
# # Using GridSearchCV:

# %%
params = {'n_estimators' : [100,110,80], 'criterion' : ["squared_error", "absolute_error"]}

rf_grd = GridSearchCV(rf, param_grid = params, cv=5)
rf_grd.fit(x_train, y_train)
print('best params : ', rf_grd.best_params_)
# Out:
# best params :  {'criterion': 'squared_error', 'n_estimators': 100}

# %%
grid_rf_best = rf_grd.best_estimator_

grid_rf_best.fit(x_train, y_train)

y_pred = grid_rf_best.predict(x_test)

print('R2 Score:', r2_score(y_test, y_pred))
print('Mean absolute error:', mean_absolute_error(y_test, y_pred))
print('Mean square error:', mean_squared_error(y_test, y_pred))
print('Root mean square error:',np.sqrt( mean_squared_error(y_test, y_pred)))
# Out:
# R2 Score: 0.8731430862516049
# Mean absolute error: 105.07840152235966
# Mean square error: 45891.57876070409
# Root mean square error: 214.2231984653018

# %%
# Observation

# Slight improvement in the scores

# %% [markdown]
# # Using Support Vector Regression():

# %%
from sklearn.svm import SVR
svr_rbf = SVR(kernel='rbf')
svr_rbf.fit(x_train, y_train)

y_pred = svr_rbf.predict(x_test)

print('R2 Score:', r2_score(y_test, y_pred))
print('Mean absolute error:', mean_absolute_error(y_test, y_pred))
print('Mean square error:', mean_squared_error(y_test, y_pred))
# Out:
# R2 Score: 0.2816014176546544
# Mean absolute error: 224.0081142886578
# Mean square error: 259886.8611029619

# %%
from sklearn.svm import SVR
svr_poly = SVR(kernel='poly')
svr_poly.fit(x_train, y_train)

y_pred = svr_poly.predict(x_test)

print('R2 Score:', r2_score(y_test, y_pred))
print('Mean absolute error:', mean_absolute_error(y_test, y_pred))
print('Mean square error:', mean_squared_error(y_test, y_pred))
# Out:
# R2 Score: 0.30134954114513435
# Mean absolute error: 244.31202119016396
# Mean square error: 252742.80771429953

# %%
from sklearn.svm import SVR
svr_lin = SVR(kernel='linear', )
svr_lin.fit(x_train, y_train)

y_pred = svr_lin.predict(x_test)

print('R2 Score:', r2_score(y_test, y_pred))
print('Mean absolute error:', mean_absolute_error(y_test, y_pred))
print('Mean square error:', mean_squared_error(y_test, y_pred))
# Out:
# R2 Score: 0.6518257815755328
# Mean absolute error: 152.3525286771808
# Mean square error: 125955.01573500295

# %% [markdown]
# # Using GridSearchCV:

# %%
params = {'gamma':['scale', 'auto'],'C':[1.0,0.1], 'kernel':['linear']}

svr_grd = GridSearchCV(svr_lin, param_grid = params, cv=5)
svr_grd.fit(x_train, y_train)
print('best params : ', svr_grd.best_params_)
# Out:
# best params :  {'C': 1.0, 'gamma': 'scale', 'kernel': 'linear'}

# %%
grid_svr_best = svr_grd.best_estimator_
grid_svr_best.fit(x_train, y_train)

y_pred = grid_svr_best.predict(x_test)

print('R2 Score:', r2_score(y_test, y_pred))
print('Mean absolute error:', mean_absolute_error(y_test, y_pred))
print('Mean square error:', mean_squared_error(y_test, y_pred))
print('Root mean square error:',np.sqrt( mean_squared_error(y_test, y_pred)))
# Out:
# R2 Score: 0.6518257815755328
# Mean absolute error: 152.3525286771808
# Mean square error: 125955.01573500295
# Root mean square error: 354.9014169244791

# %%
# Observation

# No improvement in scores

# %% [markdown]
# # Using GradientBoostingRegressor()

# %%
from sklearn.ensemble import  GradientBoostingRegressor

gbdt= GradientBoostingRegressor()
gbdt.fit(x_train, y_train)

y_pred = gbdt.predict(x_test)

print('R2 Score:', r2_score(y_test, y_pred))
print('Mean absolute error:', mean_absolute_error(y_test, y_pred))
print('Mean square error:', mean_squared_error(y_test, y_pred))
print('Root mean square error:',np.sqrt( mean_squared_error(y_test, y_pred)))
# Out:
# R2 Score: 0.8778166516208545
# Mean absolute error: 112.33272074882184
# Mean square error: 44200.876323613375
# Root mean square error: 210.24004452913667

# %% [markdown]
# # Using GridSearchCV:

# %%
params = {'loss': ['squared_error', 'absolute_error'], 'n_estimators':[100,130]}

gbdt_grd = GridSearchCV(gbdt, param_grid = params, cv=5)
gbdt_grd.fit(x_train, y_train)
print('best params : ', gbdt_grd.best_params_)
# Out:
# best params :  {'loss': 'squared_error', 'n_estimators': 130}

# %%
grid_gbdt_best = gbdt_grd.best_estimator_

grid_gbdt_best.fit(x_train, y_train)

y_pred = grid_gbdt_best.predict(x_test)

print('R2 Score:', r2_score(y_test, y_pred))
print('Mean absolute error:', mean_absolute_error(y_test, y_pred))
print('Mean square error:', mean_squared_error(y_test, y_pred))
print('Root mean square error:',np.sqrt( mean_squared_error(y_test, y_pred)))
# Out:
# R2 Score: 0.8800979642280471
# Mean absolute error: 111.12713348682094
# Mean square error: 43375.59188229067
# Root mean square error: 208.26807696401931

# %%
# Observations:

# Scores have improved

# %% [markdown]
# # Using AdaBoostRegressor():

# %%
from sklearn.ensemble import AdaBoostRegressor

ada= AdaBoostRegressor()
ada.fit(x_train, y_train)

y_pred = ada.predict(x_test)

print('R2 Score:', r2_score(y_test, y_pred))
print('Mean absolute error:', mean_absolute_error(y_test, y_pred))
print('Mean square error:', mean_squared_error(y_test, y_pred))
print('Root mean square error:',np.sqrt( mean_squared_error(y_test, y_pred)))
# Out:
# R2 Score: 0.8500428171806904
# Mean absolute error: 135.16848845018438
# Mean square error: 54248.29962153096
# Root mean square error: 232.91264375626102

# %% [markdown]
# # Using GridSearchCV:

# %%
params = { 'loss' : ['linear', 'square'], 'learning_rate': [0.1,0.01] ,
        'n_estimators':[50,60] }

ada_grd = GridSearchCV(ada, param_grid = params, cv=5)
ada_grd.fit(x_train, y_train)
print('best params : ', ada_grd.best_params_)
# Out:
# best params :  {'learning_rate': 0.1, 'loss': 'linear', 'n_estimators': 50}

# %%
grid_ada_best = ada_grd.best_estimator_

grid_ada_best.fit(x_train, y_train)

y_pred = grid_ada_best.predict(x_test)

print('R2 Score:', r2_score(y_test, y_pred))
print('Mean absolute error:', mean_absolute_error(y_test, y_pred))
print('Mean square error:', mean_squared_error(y_test, y_pred))
print('Root mean square error:',np.sqrt( mean_squared_error(y_test, y_pred)))
# Out:
# R2 Score: 0.8433829534438717
# Mean absolute error: 135.69596071625713
# Mean square error: 56657.562563399115
# Root mean square error: 238.02849107491127

# %%
# Observations:

# Scores have not improved

# %% [markdown]
# # As per 7 different regression model we can see that the model with maximum R2 score and minimum RMSE value is Random Forest Regression() and GradientBoostingRegressor().

# %%
# Let's check the cross validation score before final prediction.

# %% [markdown]
# # Cross Validation:

# %%
from sklearn.model_selection import cross_val_score

all_models = [grid_lin_best , grid_dt_best , knn , rf , grid_svr_best , grid_gbdt_best, grid_ada_best]

for i in all_models:
    cvscore = cross_val_score(i, x_scale,y, cv = 5)
    print('Cross Validation Score of :',i)
    print("\n Cross Validation Score : " ,cvscore)
    print("\nMean CV Score :",cvscore.mean())
    print("\nStd deviation :",cvscore.std())
    print("\n-----------")
    print("-----------")
# Out:
# Cross Validation Score of : LinearRegression(fit_intercept='True', n_jobs=1)
#
#  Cross Validation Score :  [-2.87596767e+19  7.52709920e-01  7.41912555e-01  6.50788592e-01
#  -1.05753496e+25]
#
# Mean CV Score : -2.1150756801109468e+24
#
# Std deviation : 4.2301369803982273e+24
#
# -----------
# -----------
# Cross Validation Score of : DecisionTreeRegressor(min_samples_leaf=2, splitter='random')
#
#  Cross Validation Score :  [0.71990797 0.77976124 0.79911794 0.81851831 0.67819839]
#
# Mean CV Score : 0.7591007721860288
#
# Std deviation : 0.05223015076206742
#
# -----------
# -----------
# Cross Validation Score of : KNeighborsRegressor(n_neighbors=12)
#
#  Cross Validation Score :  [0.68105894 0.69233803 0.78965761 0.69452206 0.68156827]
#
# Mean CV Score : 0.7078289815676377
#
# Std deviation : 0.04127766407894864
#
# -----------
# -----------
# Cross Validation Score of : RandomForestRegressor()
#
#  Cross Validation Score :  [0.77972605 0.84996946 0.85638193 0.85465896 0.8653251 ]
#
# Mean CV Score : 0.8412122999317313
#
# Std deviation : 0.031143553279501485
#
# -----------
# -----------
# Cross Validation Score of : SVR(kernel='linear')
#
#  Cross Validation Score :  [0.71181673 0.69985737 0.71334971 0.54965681 0.83423706]
#
# Mean CV Score : 0.7017835359931784
#
# Std deviation : 0.09047058110557472
#
# -----------
# -----------
# Cross Validation Score of : GradientBoostingRegressor(n_estimators=130)
#
#  Cross Validation Score :  [0.7762997  0.84209789 0.85309578 0.81045721 0.86597149]
#
# Mean CV Score : 0.8295844124554795
#
# Std deviation : 0.03236819974019104
#
# -----------
# -----------
# Cross Validation Score of : AdaBoostRegressor(learning_rate=0.1)
#
#  Cross Validation Score :  [0.67223146 0.83056326 0.81379791 0.82062343 0.80619706]
#
# Mean CV Score : 0.7886826237061586
#
# Std deviation : 0.05877517931749259
#
# -----------
# -----------

# %% [markdown]
# # Conclusion:

# %% [markdown]
# # Our final model is Random Forest Regressor() for this particular dataset for calculating Average_Cost_for_two_Regression.

# %% [markdown]
# # Final Model:

# %%
y_pred = rf.predict(x_test)
y_pred
# Out:
# array([632. , 822. , 658. , ..., 821.5, 221. , 637.5])

# %%
# Let's visualize the variation of actual test data and predicted data
plt.figure(figsize=(10,5))
sns.scatterplot(y_test.round(2), y_pred)
plt.xlabel("Actual rainfall", fontsize= 15)
plt.ylabel("Predicted rainfall",fontsize= 15)
plt.title("Actual & Predicted rainfall" , fontsize= 15, fontweight= 'bold')
plt.show()

# %%
print('Final R2 Score:', r2_score(y_test, y_pred))
print('\nFinal Mean absolute error:', mean_absolute_error(y_test, y_pred))
print('\nFinal Mean square error:', mean_squared_error(y_test, y_pred))
print('\nFinal Root mean square error:',np.sqrt( mean_squared_error(y_test, y_pred)))
# Out:
# Final R2 Score: 0.8723455073643314
#
# Final Mean absolute error: 105.08494291151284
#
# Final Mean square error: 46180.10977759277
#
# Final Root mean square error: 214.89557877628096

# %% [markdown]
# # Load and save the model

# %%
# Now , let's save the model for future use.

# %%
import pickle
pickle.dump(grid_rf_best, open("Average_Cost_for_two_Regression_model", "wb"))

load_Average_Cost_for_two_Regression_model= pickle.load(open("Average_Cost_for_two_Regression_model", "rb"))

# %%
y_pred = load_Average_Cost_for_two_Regression_model.predict(x_test)

y_test = np.array(y_test)
data_prediction_by_model = pd.DataFrame()
data_prediction_by_model["Predicted Values"] = y_pred
data_prediction_by_model["Actual Values"] = y_test
data_prediction_by_model.sample(n=6)
# Out:
#       Predicted Values  Actual Values
# 1223             772.0            700
# 492              302.0            400
# 1893             580.5            600
# 1304             304.0            400
# 1462            2331.0           2200
# 211              580.5            500
